# %%
import requests

# %%
requests
# Out:
# <module 'requests' from 'c:\\Users\\pelik\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\requests\\__init__.py'>

# %%
result = requests.get('https://google.com')
result
# Out:
# <Response [200]>

# %%
result.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="de-AT"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="UkR3KxY1IKH_KxMB5Rl2wg">(function(){var _g={kEI:\'PhjkZsDLNvOJ9u8PxdXr6A8\',kEXPI:\'0,3700270,679,432,3,48,538613,2872,2891,8348,34680,30022,219727,6699,41949,68695,13670,2006,8155,23350,22436,9779,45601,17056,76209,15816,1804,7763,6597,6651,6083,8174,11814,1635,29276,14181,1483,6114,5218977,148,2,95,43,5991146,2841697,17,133,5,6,6,4,5,27980262,1008,15664,43887,3,1603,3,2124363,23029351,12799,19163,5352,2,21862,10199,21439,45086,15165,8181,71096,6757,156,2483,13415,89,7736,9140,4598,328,3217,5,1238,1766,7586,5,2827,6599,2657,409,518,5720,1669,5634,686,6677,1119,3,3015,2694,4480,11157,709,683,659,5849,7858,49,308,1856,2,9,13411,2376,1486,316,663,528,1563,5200,3769,1907,6854,440,6,1093,4972,2388,156,29
# ...
